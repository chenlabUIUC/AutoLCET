# %%
# Mount Google Drive to access files
from google.colab import drive
import os
drive.mount('/content/drive', force_remount=True)

# Change the current directory to the script folder in Google Drive
# **NOTE:** You may need to change the path below to match your specific script location
os.chdir('drive/My Drive/ML3D/2025')

# List the contents of the current directory to verify the change
os.listdir('.')
# Out:
# Mounted at /content/drive
# ['prediction',
#  'test',
#  'augmentation.zip',
#  'augmentation',
#  'model.keras',
#  'train.ipynb']

# %%
# Unzip the augmentation data
# This assumes you have a zip file named 'augmentation.zip' in the current directory
# !unzip augmentation.zip

# %%
# Import necessary libraries for building and training the 3D U-Net model
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, CSVLogger
from tensorflow.keras import backend as keras
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tifffile as tif
import glob
import cv2
from skimage.transform import resize

# %%
# Define the 3D U-Net model architecture
def get_unet():
    # Input layer with shape (128, 128, 128, 1)
    inputs = Input((128, 128, 128,1))

    # Encoder path
    conv1 = Conv3D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv3D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2))(conv1)

    conv2 = Conv3D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv3D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2))(conv2)

    conv3 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conv3)

    conv4 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = Conv3D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop1 = Dropout(0.5)(conv4)

    # Decoder path
    upol1 = UpSampling3D(size = (2, 2, 2))(drop1)
    up1 = Conv3D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(upol1)
    # Concatenate with the corresponding encoder layer
    merge1 = concatenate([conv3,up1],axis=4)
    conv5 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge1)
    conv5 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)

    upol2 = UpSampling3D(size=(2, 2,2))(conv5)
    up2 = Conv3D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(upol2)
    # Concatenate with the corresponding encoder layer
    merge2 = concatenate([conv2,up2],axis=4)
    conv6 = Conv3D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge2)
    conv6 = Conv3D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    upol3 = UpSampling3D(size=(2, 2,2))(conv6)
    up3 = Conv3D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(upol3)
    # Concatenate with the corresponding encoder layer
    merge3 = concatenate([conv1,up3],axis=4)
    conv7 = Conv3D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge3)
    conv7 = Conv3D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    # Output layer with 3 classes (for segmentation)
    output = Conv3D(3, 1, activation = 'softmax')(conv7)

    # Create the model
    model = Model(inputs = inputs, outputs = output)

    # Compile the model with Adam optimizer and categorical crossentropy loss
    model.compile(optimizer = Adam(learning_rate = 1e-4), loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])

    return model

# %%
# Load and preprocess the augmented training data
fileList = glob.glob('augmentation/*.tif')
imgs = np.ndarray((len(fileList),128,128,128,1), dtype='float32')
labels = np.ndarray((len(fileList),128,128,128,3), dtype='bool')

i = 0
for name in fileList:
  # Read the TIFF image and its channels
  img = np.array(cv2.imreadmulti(name)[1])

  # Extract the third channel (index 2) as the input image and normalize
  imgs[i] = np.expand_dims(img[:,:,:,2],axis = 3)/255

  # Extract the first two channels (index 0 and 1) as labels for two classes
  labels[i,:,:,:,0] = (img[:,:,:,0]/255).astype('bool')
  labels[i,:,:,:,1] = (img[:,:,:,1]/255).astype('bool')

  # Create the third label channel as the inverse of the union of the first two
  labels[i,:,:,:,2] = np.logical_not(np.logical_or(img[:,:,:,0] , img[:,:,:,1]))

  i+=1
  if (i+1) % 10 == 0:
    print('Done: {0}/{1} images'.format(i+1, len(fileList)))
# Out:
# Done: 10/420 images
# Done: 20/420 images
# Done: 30/420 images
# Done: 40/420 images
# Done: 50/420 images
# Done: 60/420 images
# Done: 70/420 images
# Done: 80/420 images
# Done: 90/420 images
# Done: 100/420 images
# Done: 110/420 images
# Done: 120/420 images
# Done: 130/420 images
# Done: 140/420 images
# Done: 150/420 images
# Done: 160/420 images
# Done: 170/420 images
# Done: 180/420 images
# Done: 190/420 images
# Done: 200/420 images
# Done: 210/420 images
# Done: 220/420 images
# Done: 230/420 images
# Done: 240/420 images
# Done: 250/420 images
# Done: 260/420 images
# Done: 270/420 images
# Done: 280/420 images
# Done: 290/420 images
# Done: 300/420 images
# Done: 310/420 images
# Done: 320/420 images
# Done: 330/420 images
# Done: 340/420 images
# Done: 350/420 images
# Done: 360/420 images
# Done: 370/420 images
# Done: 380/420 images
# Done: 390/420 images
# Done: 400/420 images
# Done: 410/420 images
# Done: 420/420 images

# %%
# Create the U-Net model
model = get_unet()

# Display the model summary
model.summary()

# Define a ModelCheckpoint callback to save the best model during training
model_checkpoint = ModelCheckpoint('model.keras', monitor='categorical_accuracy',verbose=1, save_best_only=False)

# Train the model
# Using a batch size of 1 due to memory constraints with 3D data
# Training for 25 epochs with a 10% validation split
model.fit(imgs,labels, batch_size=1, epochs=25, verbose=1, shuffle=True, validation_split = 0.1, callbacks=model_checkpoint)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 128,  │              0 │ -                      │
# │                           │ 1)                     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d (Conv3D)           │ (None, 128, 128, 128,  │          1,792 │ input_layer[0][0]      │
# │                           │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_1 (Conv3D)         │ (None, 128, 128, 128,  │        110,656 │ conv3d[0][0]           │
# │                           │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d             │ (None, 64, 64, 64, 64) │              0 │ conv3d_1[0][0]         │
# │ (MaxPooling3D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_2 (Conv3D)         │ (None, 64, 64, 64,     │        221,312 │ max_pooling3d[0][0]    │
# │                           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_3 (Conv3D)         │ (None, 64, 64, 64,     │        442,496 │ conv3d_2[0][0]         │
# │                           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d_1           │ (None, 32, 32, 32,     │              0 │ conv3d_3[0][0]         │
# │ (MaxPooling3D)            │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_4 (Conv3D)         │ (None, 32, 32, 32,     │        884,992 │ max_pooling3d_1[0][0]  │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_5 (Conv3D)         │ (None, 32, 32, 32,     │      1,769,728 │ conv3d_4[0][0]         │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_6 (Conv3D)         │ (None, 32, 32, 32,     │      1,769,728 │ conv3d_5[0][0]         │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling3d_2           │ (None, 16, 16, 16,     │              0 │ conv3d_6[0][0]         │
# │ (MaxPooling3D)            │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_7 (Conv3D)         │ (None, 16, 16, 16,     │      1,769,728 │ max_pooling3d_2[0][0]  │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_8 (Conv3D)         │ (None, 16, 16, 16,     │      1,769,728 │ conv3d_7[0][0]         │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_9 (Conv3D)         │ (None, 16, 16, 16,     │      3,539,456 │ conv3d_8[0][0]         │
# │                           │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 16, 16, 16,     │              0 │ conv3d_9[0][0]         │
# │                           │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling3d             │ (None, 32, 32, 32,     │              0 │ dropout[0][0]          │
# │ (UpSampling3D)            │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_10 (Conv3D)        │ (None, 32, 32, 32,     │      7,078,400 │ up_sampling3d[0][0]    │
# │                           │ 512)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 32,     │              0 │ conv3d_6[0][0],        │
# │                           │ 768)                   │                │ conv3d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_11 (Conv3D)        │ (None, 32, 32, 32,     │      5,308,672 │ concatenate[0][0]      │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_12 (Conv3D)        │ (None, 32, 32, 32,     │      1,769,728 │ conv3d_11[0][0]        │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling3d_1           │ (None, 64, 64, 64,     │              0 │ conv3d_12[0][0]        │
# │ (UpSampling3D)            │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_13 (Conv3D)        │ (None, 64, 64, 64,     │      1,769,728 │ up_sampling3d_1[0][0]  │
# │                           │ 256)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 64,     │              0 │ conv3d_3[0][0],        │
# │ (Concatenate)             │ 384)                   │                │ conv3d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_14 (Conv3D)        │ (None, 64, 64, 64,     │      1,327,232 │ concatenate_1[0][0]    │
# │                           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_15 (Conv3D)        │ (None, 64, 64, 64,     │        442,496 │ conv3d_14[0][0]        │
# │                           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling3d_2           │ (None, 128, 128, 128,  │              0 │ conv3d_15[0][0]        │
# │ (UpSampling3D)            │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_16 (Conv3D)        │ (None, 128, 128, 128,  │        442,496 │ up_sampling3d_2[0][0]  │
# │                           │ 128)                   │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 128,  │              0 │ conv3d_1[0][0],        │
# │ (Concatenate)             │ 192)                   │                │ conv3d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_17 (Conv3D)        │ (None, 128, 128, 128,  │        331,840 │ concatenate_2[0][0]    │
# │                           │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_18 (Conv3D)        │ (None, 128, 128, 128,  │        110,656 │ conv3d_17[0][0]        │
# │                           │ 64)                    │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3d_19 (Conv3D)        │ (None, 128, 128, 128,  │            195 │ conv3d_18[0][0]        │
# │                           │ 3)                     │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 30,861,059 (117.73 MB)
#  Trainable params: 30,861,059 (117.73 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9187 - loss: 0.3984
# Epoch 1: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 169s 357ms/step - categorical_accuracy: 0.9187 - loss: 0.3979 - val_categorical_accuracy: 0.9847 - val_loss: 0.0368
# Epoch 2/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9663 - loss: 0.0817
# Epoch 2: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9663 - loss: 0.0817 - val_categorical_accuracy: 0.9836 - val_loss: 0.0398
# Epoch 3/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9730 - loss: 0.0671
# Epoch 3: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9730 - loss: 0.0671 - val_categorical_accuracy: 0.9830 - val_loss: 0.0414
# Epoch 4/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9765 - loss: 0.0580
# Epoch 4: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9765 - loss: 0.0580 - val_categorical_accuracy: 0.9829 - val_loss: 0.0495
# Epoch 5/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9778 - loss: 0.0546
# Epoch 5: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9778 - loss: 0.0546 - val_categorical_accuracy: 0.9851 - val_loss: 0.0357
# Epoch 6/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9800 - loss: 0.0485
# Epoch 6: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9800 - loss: 0.0485 - val_categorical_accuracy: 0.9856 - val_loss: 0.0353
# Epoch 7/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9803 - loss: 0.0477
# Epoch 7: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9803 - loss: 0.0477 - val_categorical_accuracy: 0.9846 - val_loss: 0.0402
# Epoch 8/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9816 - loss: 0.0448
# Epoch 8: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9816 - loss: 0.0448 - val_categorical_accuracy: 0.9878 - val_loss: 0.0325
# Epoch 9/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9812 - loss: 0.0458
# Epoch 9: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9812 - loss: 0.0457 - val_categorical_accuracy: 0.9841 - val_loss: 0.0396
# Epoch 10/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9821 - loss: 0.0434
# Epoch 10: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9821 - loss: 0.0434 - val_categorical_accuracy: 0.9873 - val_loss: 0.0311
# Epoch 11/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9830 - loss: 0.0408
# Epoch 11: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9830 - loss: 0.0408 - val_categorical_accuracy: 0.9887 - val_loss: 0.0257
# Epoch 12/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9842 - loss: 0.0380
# Epoch 12: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9842 - loss: 0.0380 - val_categorical_accuracy: 0.9890 - val_loss: 0.0311
# Epoch 13/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9844 - loss: 0.0374
# Epoch 13: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.9844 - loss: 0.0374 - val_categorical_accuracy: 0.9897 - val_loss: 0.0267
# Epoch 14/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9832 - loss: 0.0410
# Epoch 14: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 297ms/step - categorical_accuracy: 0.
saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9917 - loss: 0.0194 - val_categorical_accuracy: 0.9910 - val_loss: 0.0333
# Epoch 37/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9917 - loss: 0.0196
# Epoch 37: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 296ms/step - categorical_accuracy: 0.9917 - loss: 0.0196 - val_categorical_accuracy: 0.9904 - val_loss: 0.0307
# Epoch 38/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - categorical_accuracy: 0.9914 - loss: 0.0200
# Epoch 38: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 296ms/step - categorical_accuracy: 0.9914 - loss: 0.0200 - val_categorical_accuracy: 0.9924 - val_loss: 0.0241
# Epoch 39/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9924 - loss: 0.0178
# Epoch 39: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 296ms/step - categorical_accuracy: 0.9924 - loss: 0.0178 - val_categorical_accuracy: 0.9913 - val_loss: 0.0311
# Epoch 40/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9919 - loss: 0.0190
# Epoch 40: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9919 - loss: 0.0190 - val_categorical_accuracy: 0.9912 - val_loss: 0.0259
# Epoch 41/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9921 - loss: 0.0186
# Epoch 41: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 296ms/step - categorical_accuracy: 0.9921 - loss: 0.0186 - val_categorical_accuracy: 0.9909 - val_loss: 0.0346
# Epoch 42/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9925 - loss: 0.0173
# Epoch 42: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9925 - loss: 0.0173 - val_categorical_accuracy: 0.9906 - val_loss: 0.0384
# Epoch 43/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9923 - loss: 0.0179
# Epoch 43: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9923 - loss: 0.0179 - val_categorical_accuracy: 0.9920 - val_loss: 0.0285
# Epoch 44/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9925 - loss: 0.0175
# Epoch 44: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9925 - loss: 0.0175 - val_categorical_accuracy: 0.9914 - val_loss: 0.0345
# Epoch 45/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9931 - loss: 0.0161
# Epoch 45: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9931 - loss: 0.0161 - val_categorical_accuracy: 0.9925 - val_loss: 0.0216
# Epoch 46/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9926 - loss: 0.0174
# Epoch 46: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9926 - loss: 0.0174 - val_categorical_accuracy: 0.9917 - val_loss: 0.0274
# Epoch 47/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9924 - loss: 0.0178
# Epoch 47: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9924 - loss: 0.0178 - val_categorical_accuracy: 0.9925 - val_loss: 0.0266
# Epoch 48/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9932 - loss: 0.0158
# Epoch 48: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9932 - loss: 0.0158 - val_categorical_accuracy: 0.9914 - val_loss: 0.0341
# Epoch 49/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9933 - loss: 0.0156
# Epoch 49: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 112s 295ms/step - categorical_accuracy: 0.9933 - loss: 0.0156 - val_categorical_accuracy: 0.9905 - val_loss: 0.0373
# Epoch 50/50
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - categorical_accuracy: 0.9932 - loss: 0.0157
# Epoch 50: saving model to model.keras
# 378/378 ━━━━━━━━━━━━━━━━━━━━ 111s 295ms/step - categorical_accuracy: 0.9932 - loss: 0.0157 - val_categorical_accuracy: 0.9906 - val_loss: 0.0409

# %%
# Load the trained model
model = load_model('model.keras')

# Get a list of test image files
nameList = glob.glob('test/*.tif')

# Iterate through each test image
for name in nameList:
  # Read the test image
  img = np.array(cv2.imreadmulti(name)[1])

  # Expand dimensions and normalize the image
  img = np.expand_dims(img[:,:,:],axis = [0,4])/255

  # Get the original size of the image
  sz = img.shape[1]

  # Resize the image to 128x128x128 if it's not already
  if sz != 128:
    img = resize(img.squeeze(), (128,128,128), mode='constant', anti_aliasing=True)
    img = np.expand_dims(img,axis = [0,4])

  # Predict the segmentation mask
  pred = model.predict(img, batch_size=1)

  # Clip the predictions to be within [0, 1]
  pred[pred<0] = 0
  pred[pred>1] = 1

  # Resize the prediction back to the original image size if necessary
  if sz != 128:
    pred = resize(pred[0], (sz,sz,sz), mode='constant', anti_aliasing=True)

  # Save the prediction as a TIFF file
  # The filename is extracted from the original test image filename
  tif.imwrite('prediction/'+name[name.find('/')+1:], (pred*255).astype(np.uint8))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
